# %% [markdown]
# # Pendulo

# %%
import math as math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Variables

# %%
g=9.81 #gravedad
l=1  #longitud del pendulo
w=(g/l)**(1/2)

dt=0.1 #intervalos de tiempo
t = np.arange(0,6+dt,dt) #tiempo
#print('t =', t)

tl=t.size  #time lenght
X=np.zeros(tl)
i=0  
#print('tl=',tl)
#print('X=',X)

# %% [markdown]
# Condiciones iniciales

# %%
A=1 
B=0
x0=A  #posición inicial
vx0=B  #velocidad inicial
#ax0=

# %% [markdown]
# Ecuaciones

# %%
#ax=-A*w**2*cos(w*t)
#vx=-A*w*sin(wt)

# %%
for n in t:
    x=A*np.cos(w*n)
    X[i]=x
    i=i+1
    
print('X =', X)
# Out:
# X = [ 1.          0.95134967  0.81013241  0.59008873  0.31262904  0.00475033
#  -0.30359058 -0.58239193 -0.80452617 -0.94837949 -0.99995487 -0.95423399
#  -0.81566552 -0.59773226 -0.32163927 -0.01425057  0.29452472  0.57464257
#   0.79884732  0.9453237   0.99981948  0.95703217  0.821125    0.60532184
#   0.33062048  0.02374952 -0.28543228 -0.56684133 -0.79309636 -0.94218259
#  -0.99959384 -0.95974396 -0.82651037 -0.61285679 -0.33957184 -0.03324633
#   0.27631408  0.55898894  0.78727381  0.93895643  0.99927798  0.96236913
#   0.83182114  0.62033641  0.34849255  0.04274013 -0.26717093 -0.55108608
#  -0.7813802  -0.93564552 -0.99887192 -0.96490743 -0.83705683 -0.62776004
#  -0.3573818  -0.05223008  0.25800367  0.54313349  0.77541606  0.93225016
#   0.9983757 ]

# %% [markdown]
# Plot

# %%
plt.plot(t,X)
plt.xlabel('Time')
plt.ylabel('Position')
plt.show(1)
